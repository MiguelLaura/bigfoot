# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

from datetime import datetime

import csv
from fog.tokenizers import WordTokenizer
import networkx as nx
from ipysigma import Sigma
from pelote import (
    graph_to_edges_dataframe,
    graph_to_nodes_dataframe,
    crop_to_largest_connected_component,
    monopartite_projection,
    global_threshold_sparsification
)

import re
import math
from tqdm import tqdm
from collections import defaultdict, Counter

# %%
stop_list = ["'m", "'re", "'s", 'report', 'person', 'smh', 'it', 'great', 'there', 'days', 'hate', 'look', 'most', 'phone', 'well', 'watch', "'ve", 'm', 'by', 'cause', 'got', 'out', 'too', 'will', 't', 'get', 'video', 'keep', 'care', 'song', 'd', 'mean', 'night', 'was', 'he', 'miss', 'such', 'damn', 'is', 'house', 'a', 'into', 'am', 'been', 'im', 'much', 'one', 'just', 'are', 'really', 'sleep', 'team', 'want', 'work', 'photo', 'gotta', 'its', 'niggas', 'because', 'home', 'already', 'better', 'new', 'now', '3', 'off', 'made', 'over', 'your', 'only', 'tweet', 'week', 'she', 'this', 'didn', 'does', 'god', 'ever', 'dont', 'gonna', "i'", 'after', 'and', 'hard', 'help', 'how', 'in', 'their', 'any', 'him', 'bout', 'never', 'when', 'if', 'take', 'everyone', 'something', 'what', 'talk', "won't", 'they', 's', 'so', 'can', 'show', 'r', 'next', 'tell', 'them', 'guys', 'again', 'than', 'before', 'nigga', 'p', 'thing', 'g', 'w', 'friends', 'best', 'being', 'life', 'said', 'the', 'i', 'l', 'more', 'should', 'play', 'ross', 'someone', 'think', 'on', 'were', 'where', 'far', 'fuck', 'right', 'with', 'school', 'her', 'about', '2012', 'put', 'way', 'fucking', 'twitter', 'back', 'would', 'don', 'or', 'us', 'to', 'e', 'free', 'need', 'thank', 'who', '0', 'hip', 'every', 'gone', 'o', 'bad', 'head', 'at', 'ass', 'ready', 'day', 'll', 'heart', 'his', 'time', "'d", "'ll", 'my', 'f', 'all', 'has', 've', 'other', 'going', 'having', 'shit', 'an', 'go', 'wait', 'did', 'like', 'many', 'follow', 'last', 'morning', 'we', 'away', 'tomorrow', 'you', 'cool', 'no', 'that', 'feel', 'here', 'real', 'had', "don't", 'do', 're', 'live', "can't", 'news', 'lt', 'today', 'love', 'why', 'world', 'check', 'still', 'for', 'know', 'see', 'wish', 'have', 'cant', 'give', 'things', 'two', 'down', 'stop', 'say', 'class', 'done', 'thanks', 'looking', 'up', 'be', 'start', 'find', 'nothing', '1', 'tho', 'though', '2', 'won', 'another', 'hair', 'watching', 'please', 'make', 'then', 'even', 'people', 'let', 'year', 'everything', 'h', 'big', 'girls', 'wanna', 'could', 'from', 'our', 'ain', 'but', 'c', 'doing', 'hop', 'old', 'some', 'of', 'good', 'nice', 'n', 'b', 'as', 'money', 'girl', 'around', 'u', 'face', 'bitch', 'not', 'game', 'always', 'j', 'long', 'lmao', 'same', 'k', 'little', 'getting', 'win', 'these', 'hope', 'amp', 'tonight', 'man', 'come']
NUMBER_PARENTHESIS = re.compile("[0-9\(\)]")

tokenizer = WordTokenizer(lower=True, unidecode=True, drop=["punct", "number"], stoplist=stop_list)

report_class = {}

tokens = Counter()
tokens_per_report = defaultdict(set)
class_per_token = defaultdict(set)

with open("../data/bigfoot.csv", "r") as f:
    reader = csv.DictReader(f)
    for line in tqdm(reader, total=5021):

        if line["classification"] == "Class C":
            continue

        report_class[line["number"]] = line["classification"]

        # changer l'attribut dans line pour faire pareil avec location_details et observe
        for _, token in tokenizer.tokenize(line["title"]):
            if not NUMBER_PARENTHESIS.search(token):
                tokens[token] += 1
                class_per_token[token].add(line["classification"])
                tokens_per_report[line["number"]].add(token)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5021/5021 [00:02<00:00, 2429.95it/s]

# %%
dict_tokens = {k: v for k, v in tokens.most_common() if v > 5}
dict_tokens
# Out:
# {'near': 1788,
#  'sighting': 1168,
#  'possible': 871,
#  'encounter': 421,
#  'while': 382,
#  'lake': 351,
#  'vocalizations': 342,
#  'outside': 328,
#  'daylight': 322,
#  'road': 302,
#  'large': 291,
#  'creature': 289,
#  'hunter': 267,
#  'river': 252,
#  'heard': 246,
#  'motorist': 236,
#  'nighttime': 224,
#  'family': 188,
#  'hear': 186,
#  'animal': 185,
#  'hears': 182,
#  'forest': 179,
#  'late': 171,
#  'early': 164,
#  'park': 156,
#  'national': 151,
#  'recalls': 146,
#  'hunters': 140,
#  'tracks': 140,
#  'campers': 136,
#  'along': 135,
#  'sasquatch': 134,
#  'crossing': 134,
#  'close': 134,
#  'daytime': 133,
#  'woman': 131,
#  'state': 130,
#  'found': 129,
#  'north': 129,
#  'bigfoot': 128,
#  'footprints': 126,
#  'strange': 125,
#  'sees': 119,
#  'witness': 118,
#  'deer': 118,
#  'creek': 117,
#  'couple': 116,
#  'memory': 116,
#  'area': 111,
#  'young': 111,
#  'tall': 107,
#  'told': 107,
#  'loud': 107,
#  'south': 103,
#  'figure': 103,
#  'vocalization': 96,
#  'knocks': 95,
#  'hairy': 94,
#  'describes': 93,
#  'east': 90,
#  'encounters': 90,
#  'mountain': 82,
#  'evening': 82,
#  'hunting': 81,
#  'motorists': 80,
#  'wood': 79,
#  'observes': 79,
#  'west': 78,
#  'seen': 77,
#  'finds': 77,
#  'hikers': 77,
#  'bipedal': 77,
#  'screams': 75,
#  'fisherman': 74,
#  'biped': 73,
#  'camping': 73,
#  'camper': 72,
#  'rock': 72,
#  'miles': 72,
#  'driving': 71,
#  'dusk': 69,
#  'hwy': 68,
#  'afternoon': 68,
#  'walking': 67,
#  'rural': 66,
#  'witnesses': 65,
#  'three': 64,
#  'upright': 64,
#  'woods': 63,
#  'driver': 61,
#  'city': 61,
#  'camp': 61,
#  'trail': 58,
#  'fishing': 57,
#  'son': 56,
#  'footprint': 54,
#  'father': 53,
#  'snow': 53,
#  'tree': 53,
#  'multiple': 53,
#  'hiker': 52,
#  'wilderness': 52,
#  'activity': 52,
#  'scream': 52,
#  'incidents': 51,
#  'sightings': 49,
#  'stalking': 49,
#  'reports': 49,
#  'property': 49,
#  'sounds': 49,
#  'mt': 48,
#  'dark': 48,
#  'unusual': 48,
#  'highway': 48,
#  'across': 47,
#  'experience': 47,
#  'observe': 46,
#  'unknown': 46,
#  'howls': 46,
#  'window': 45,
#  'mountains': 44,
#  'childhood': 44,
#  'behind': 42,
#  'several': 42,
#  'during': 42,
#  'men': 41,
#  'fishermen': 40,
#  'car': 40,
#  'running': 39,
#  'boy': 39,
#  'observed': 39,
#  'through': 38,
#  'cross': 38,
#  'between': 38,
#  'experiences': 38,
#  'white': 37,
#  'farm': 36,
#  'wife': 36,
#  'remembers': 36,
#  'valley': 35,
#  'town': 34,
#  'campground': 34,
#  'wildlife': 34,
#  'incident': 34,
#  'track': 33,
#  'elk': 33,
#  'springs': 33,
#  'thrown': 33,
#  'youth': 33,
#  'rocks': 33,
#  'fort': 33,
#  'hiking': 32,
#  'seeing': 32,
#  'resident': 32,
#  'cabin': 32,
#  'canyon': 32,
#  'dog': 31,
#  'mother': 30,
#  'roadside': 30,
#  'foot': 30,
#  'observation': 30,
#  'husband': 30,
#  'brief': 30,
#  'fork': 30,
#  'black': 29,
#  'field': 29,
#  'pass': 29,
#  'teen': 29,
#  'truck': 28,
#  'very': 28,
#  'years': 28,
#  'four': 27,
#  'front': 27,
#  'standing': 27,
#  'riding': 27,
#  'falls': 27,
#  'county': 27,
#  'recounts': 27,
#  'st.': 27,
#  'recollection': 26,
#  'covered': 26,
#  'throwing': 26,
#  'route': 26,
#  'preserve': 26,
#  'ridge': 25,
#  'boys': 25,
#  'group': 25,
#  'daughter': 25,
#  'bow': 25,
#  'children': 24,
#  'edge': 24,
#  'hill': 24,
#  'man-like': 24,
#  'howl': 24,
#  'knocking': 24,
#  'teenager': 24,
#  'intimidation': 23,
#  'experienced': 23,
#  'run': 23,
#  'photos': 22,
#  'swamp': 22,
#  'child': 22,
#  'teens': 22,
#  'series': 21,
#  'high': 21,
#  'describe': 21,
#  'trees': 21,
#  'red': 21,
#  'ongoing': 21,
#  'reservoir': 21,
#  'bear': 21,
#  'bfro': 21,
#  'beach': 21,
#  'chased': 21,
#  'bridge': 21,
#  'indian': 20,
#  'visitor': 20,
#  'line': 20,
#  'hearing': 20,
#  'spots': 19,
#  'watches': 19,
#  'walk': 19,
#  'backyard': 19,
#  'mount': 19,
#  'approach': 19,
#  'small': 19,
#  'remote': 19,
#  'range': 19,
#  'prints': 19,
#  'side': 19,
#  'creatures': 19,
#  'reservation': 18,
#  'huge': 18,
#  'ft': 18,
#  'footsteps': 18,
#  'vocals': 18,
#  'headlights': 18,
#  'startled': 18,
#  'brothers': 18,
#  'whoops': 18,
#  'homeowner': 18,
#  'yard': 17,
#  'passenger': 17,
#  'human-like': 17,
#  'railroad': 17,
#  'ape-like': 17,
#  'teenagers': 17,
#  'bike': 17,
#  'above': 17,
#  'grove': 17,
#  'officer': 16,
#  'stand': 16,
#  'ohio': 16,
#  'spring': 16,
#  'base': 16,
#  'dawn': 15,
#  'behavior': 15,
#  'pine': 15,
#  'heavy': 15,
#  'training': 15,
#  'brown': 15,
#  'newspaper': 15,
#  'island': 15,
#  'spot': 15,
#  'campsite': 15,
#  'logging': 15,
#  'peak': 14,
#  'dogs': 14,
#  'horseback': 14,
#  'sulphur': 14,
#  'horse': 14,
#  'vehicle': 14,
#  'road-crossing': 14,
#  'awakened': 14,
#  'dirt': 14,
#  'mile': 14,
#  'juvenile': 14,
#  'crosses': 14,
#  'screaming': 14,
#  'tells': 14,
#  'atv': 14,
#  'san': 14,
#  'riders': 14,
#  'nightime': 13,
#  'repeated': 13,
#  'reported': 13,
#  'land': 13,
#  'residents': 13,
#  'knock': 13,
#  'observing': 13,
#  'tent': 13,
#  'unseen': 13,
#  'visual': 13,
#  'followed': 13,
#  'boat': 13,
#  'later': 13,
#  'border': 13,
#  'ocala': 13,
#  'flat': 12,
#  'blue': 12,
#  'playing': 12,
#  'rider': 12,
#  'trout': 12,
#  'frightening': 12,
#  'bi-pedal': 12,
#  'print': 12,
#  'soldier': 12,
#  'management': 12,
#  'grand': 12,
#  'meadows': 12,
#  'youths': 12,
#  'point': 12,
#  'country': 12,
#  'smell': 12,
#  'recall': 12,
#  'rd': 12,
#  'bowhunter': 12,
#  'squirrel': 12,
#  'animals': 12,
#  'cemetery': 12,
#  'midnight': 12,
#  'odor': 12,
#  'houston': 12,
#  'bottoms': 12,
#  'seneca': 12,
#  'sam': 12,
#  'cypress': 12,
#  'within': 11,
#  'deep': 11,
#  'ne': 11,
#  'occurrences': 11,
#  'scouting': 11,
#  'lakes': 11,
#  'trucker': 11,
#  'green': 11,
#  'salt': 11,
#  'police': 11,
#  'trip': 11,
#  'eyes': 11,
#  'fence': 11,
#  'branch': 11,
#  'ape': 11,
#  'interstate': 11,
#  'retired': 11,
#  'service': 11,
#  'saw': 11,
#  'late-night': 11,
#  'night-time': 11,
#  'huntington': 11,
#  'strawberry': 11,
#  'wayne': 10,
#  'shaking': 10,
#  'sound': 10,
#  'teenage': 10,
#  'military': 10,
#  'bank': 10,
#  'parked': 10,
#  'refuge': 10,
#  'scary': 10,
#  'five': 10,
#  'coon': 10,
#  'mine': 10,
#  'pond': 10,
#  'turkey': 10,
#  'nw': 10,
#  'worker': 10,
#  'hog': 10,
#  'calls': 10,
#  'investigator': 10,
#  'oregon': 10,
#  'approached': 10,
#  'ranch': 10,
#  'helens': 10,
#  'six': 10,
#  'working': 10,
#  'texas': 10,
#  'cornfield': 9,
#  'site': 9,
#  'backpackers': 9,
#  'legs': 9,
#  'brush': 9,
#  'under': 9,
#  'porch': 9,
#  'scat': 9,
#  'appalachian': 9,
#  'marine': 9,
#  'steps': 9,
#  'myers': 9,
#  'part': 9,
#  'cave': 9,
#  'hair-covered': 9,
#  'rt': 9,
#  'recent': 9,
#  'outskirts': 9,
#  'frightened': 9,
#  'canton': 9,
#  'living': 9,
#  'local': 9,
#  'southeast': 9,
#  'hollow': 9,
#  'clear': 9,
#  'lost': 9,
#  'owner': 9,
#  'hood': 9,
#  'summer': 9,
#  'possibly': 9,
#  'backpacker': 9,
#  'multi-witness': 9,
#  'prairie': 9,
#  'twain': 9,
#  'colorado': 9,
#  'tahoe': 9,
#  'everglades': 9,
#  'law': 8,
#  'enforcement': 8,
#  'stalked': 8,
#  'sets': 8,
#  'parkway': 8,
#  'taken': 8,
#  'startles': 8,
#  'nf': 8,
#  'uwharrie': 8,
#  'sundown': 8,
#  'adult': 8,
#  'sw': 8,
#  'pre-dawn': 8,
#  'john': 8,
#  'water': 8,
#  'scout': 8,
#  'below': 8,
#  'northeast': 8,
#  'women': 8,
#  'bedroom': 8,
#  'strip': 8,
#  'cleveland': 8,
#  'resort': 8,
#  'members': 8,
#  'traveling': 8,
#  'returning': 8,
#  'clearing': 8,
#  'nature': 8,
#  'nashville': 8,
#  'middle': 8,
#  'union': 8,
#  'college': 8,
#  'low': 8,
#  'bend': 8,
#  'columbia': 8,
#  'gorge': 8,
#  'mushroom': 8,
#  'bus': 8,
#  'fresh': 8,
#  'nights': 8,
#  'chasing': 8,
#  'duck': 8,
#  'residence': 8,
#  'sabine': 8,
#  'eagle': 8,
#  'barefoot': 8,
#  'air': 8,
#  'mud': 8,
#  'friend': 8,
#  'rainier': 8,
#  'jacksonville': 8,
#  'middleburg': 8,
#  'separate': 7,
#  'butte': 7,
#  'chase': 7,
#  'relates': 7,
#  'stick': 7,
#  'guide': 7,
#  'gold': 7,
#  'party': 7,
#  'leaves': 7,
#  'powerful': 7,
#  'sitting': 7,
#  'howling': 7,
#  'nat': 7,
#  'u.s.': 7,
#  'top': 7,
#  'monument': 7,
#  'mills': 7,
#  'pasture': 7,
#  'various': 7,
#  'gravel': 7,
#  'course': 7,
#  'pleasant': 7,
#  'few': 7,
#  'meadow': 7,
#  'hours': 7,
#  'evidence': 7,
#  'port': 7,
#  'jackson': 7,
#  'wooded': 7,
#  'sisters': 7,
#  'cedar': 7,
#  'nest': 7,
#  'call': 7,
#  'junction': 7,
#  'illinois': 7,
#  'distant': 7,
#  'coast': 7,
#  'figures': 7,
#  'views': 7,
#  'including': 7,
#  'peninsula': 7,
#  'taking': 7,
#  'upper': 7,
#  'southwest': 7,
#  'gainesville': 7,
#  'oak': 7,
#  'twilight': 7,
#  'pigeon': 7,
#  'brazos': 7,
#  'trinity': 7,
#  'lewis': 7,
#  'sugar': 7,
#  'shasta': 7,
#  'leadville': 7,
#  'florida': 7,
#  'described': 6,
#  'female': 6,
#  'virginia': 6,
#  'massive': 6,
#  'exploring': 6,
#  'moving': 6,
#  'neighborhood': 6,
#  'biologist': 6,
#  'van': 6,
#  'private': 6,
#  'sister': 6,
#  'franklin': 6,
#  'hot': 6,
#  'shaggy': 6,
#  'james': 6,
#  'employee': 6,
#  'photographs': 6,
#  'walker': 6,
#  'dam': 6,
#  'ocean': 6,
#  'abandoned': 6,
#  'seven': 6,
#  'gap': 6,
#  'golf': 6,
#  'vernon': 6,
#  'greenville': 6,
#  'security': 6,
#  'close-range': 6,
#  'boundary': 6,
#  'shawnee': 6,
#  'jump': 6,
#  'apart': 6,
#  'smells': 6,
#  'monster': 6,
#  'cuyahoga': 6,
#  'wading': 6,
#  'sketch': 6,
#  'clark': 6,
#  'corn': 6,
#  'grass': 6,
#  'eight': 6,
#  'motorcyclist': 6,
#  'lines': 6,
#  'shaken': 6,
#  'finding': 6,
#  'past': 6,
#  'photographer': 6,
#  'discovered': 6,
#  'rabbit': 6,
#  'movement': 6,
#  'eastern': 6,
#  'sandy': 6,
#  'lady': 6,
#  'washington': 6,
#  'baker': 6,
#  'winter': 6,
#  'consecutive': 6,
#  'hills': 6,
#  'article': 6,
#  'surprise': 6,
#  'bigfoots': 6,
#  'mississippi': 6,
#  'army': 6,
#  'fish': 6,
#  'bottom': 6,
#  'carson': 6,
#  'target': 6,
#  'crashing': 6,
#  'force': 6,
#  'chatter': 6,
#  'path': 6,
#  'barn': 6,
#  'nevada': 6,
#  'village': 6,
#  'former': 6,
#  'northwest': 6,
#  'ago': 6,
#  'terrifying': 6,
#  'investigation': 6,
#  'packwood': 6,
#  'morton': 6,
#  'greenwater': 6,
#  'approaching': 6,
#  'gray': 6,
#  'olympic': 6,
#  'cle': 6,
#  'yellowstone': 6,
#  'giant': 6,
#  'benton': 6,
#  'happy': 6}

# %%
pd.Series(dict_tokens).plot.hist(bins = 250)
pd.Series(dict_tokens).describe()
# Out:
# count     610.000000
# mean       39.467213
# std       105.967850
# min         6.000000
# 25%         8.000000
# 50%        12.000000
# 75%        32.000000
# max      1788.000000
# dtype: float64

# %%
g = nx.Graph()

for report, tokens_report in tokens_per_report.items():
    g.add_node(
        report,
        classification=report_class[report],
        part="report"
    )
    for token in tokens_report:
        if token in dict_tokens.keys():
            g.add_node(
                token,
                part="token"
            )
            g.add_edge(
                report,
                token
            )

print(g.order(), g.size(), nx.density(g))

crop_to_largest_connected_component(g)

Sigma(
    g,
    node_color="classification"
)
# Out:
# 4639 23997 0.0022306520425427368
# Sigma(nx.Graph with 4,636 nodes and 23,997 edges)

# %%
g_report = monopartite_projection(g, "report")

g_report.order(), g_report.size(), nx.density(g_report)
# Out:
# (4026, 3099323, 0.3825226709617301)

# %%
graph_to_edges_dataframe(g_report)
# Out:
#           source   target  weight
# 0         6496.0  66051.0       1
# 1         6496.0   7185.0       1
# 2         6496.0   7890.0       1
# 3         6496.0   8905.0       1
# 4         6496.0   9129.0       1
# ...          ...      ...     ...
# 3099318  38980.0  33187.0       2
# 3099319  38980.0  22941.0       1
# 3099320   1045.0  33187.0       2
# 3099321   1045.0  22941.0       1
# 3099322  33187.0  22941.0       1
#
# [3099323 rows x 3 columns]

# %%
graph_to_nodes_dataframe(g_report)
# Out:
#           key classification
# 0      6496.0        Class A
# 1      9765.0        Class A
# 2      4983.0        Class A
# 3     31940.0        Class A
# 4      5692.0        Class B
# ...       ...            ...
# 4021  25257.0        Class B
# 4022  38980.0        Class A
# 4023   1045.0        Class A
# 4024  33187.0        Class A
# 4025  22941.0        Class B
#
# [4026 rows x 2 columns]

# %%
g_report_thresh = global_threshold_sparsification(g_report, 4)
g_report_thresh.order(), g_report_thresh.size(), nx.density(g_report_thresh)
# Out:
# (4026, 9930, 0.0012255741407558942)

# %%
crop_to_largest_connected_component(g_report_thresh)
g_report_thresh.order(), g_report_thresh.size(), nx.density(g_report_thresh)
# Out:
# (2026, 9842, 0.004797874544501725)

# %%
Sigma(
    g_report_thresh,
    node_color="classification"
)
# Out:
# Sigma(nx.Graph with 2,026 nodes and 9,842 edges)
